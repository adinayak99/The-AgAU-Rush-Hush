# %% [markdown]
# <a href="https://colab.research.google.com/github/adinayak99/The-AgAU-Rush-Hush/blob/main/data/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install summarytools
import pandas as pd
from summarytools import tabset, dfSummary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 43.5 MB/s eta 0:00:00
# ...

# %%
# The tables show major changes in central bank reserves & reason for the change
reserve_changes_dict = pd.read_excel("Changes_latest_as_of_Mar2026_IFS.xlsx", sheet_name=None)

# Display the names of the sheets loaded
print("Sheets loaded:", list(reserve_changes_dict.keys()))

# You can access individual sheets like this:
# reserve_changes_sheet = reserve_changes_dict['Reserve_Changes']
# display(reserve_changes_sheet.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_6335/3026822049.py in <cell line: 0>()
#       1 # The tables show major changes in central bank reserves & reason for the change
# ----> 2 reserve_changes_dict = pd.read_excel("Changes_latest_as_of_Mar2026_IFS.xlsx", sheet_name=None)
#       3
#       4 # Display the names of the sheets loaded
#       5 print("Sheets loaded:", list(reserve_changes_dict.keys()))
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
# ...
